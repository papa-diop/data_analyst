# %% [markdown]
# # Data Cleaning in Pandas

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[129], line 2
#       1 import pandas as pd
# ----> 2 import phonenumbers
#
# ModuleNotFoundError: No module named 'phonenumbers'

# %%
df = pd.read_excel(r"C:\Users\LENOVO\Documents\Data Analyst\Python\Pandas\Data Cleaning\Customer Call List.xlsx")
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df2 = df.copy()

df2
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
#df2.drop(columns= "Not_Useful_Column", inplace = True)

#df2
df.drop(columns= "Not_Useful_Column", inplace = True)

# %%
#df["Last_Name"] = df["Last_Name"].str.lstrip("...")
#df["Last_Name"] = df["Last_Name"].str.lstrip("/")
#df["Last_Name"] = df["Last_Name"].str.rstrip("_")
#df2.loc["Last_Name"] = df["Last_Name"].str.strip("123/._")
#df2

df["Last_Name"] = df["Last_Name"].str.strip("123/._")
df
# Out:
#            CustomerID First_Name   Last_Name  Phone_Number  \
# 0              1001.0      Frodo     Baggins  123-545-5421
# 1              1002.0       Abed       Nadir  123/643/9775
# 2              1003.0     Walter       White    7066950392
# 3              1004.0     Dwight     Schrute  123-543-2345
# 4              1005.0        Jon        Snow  876|678|3469
# 5              1006.0        Ron     Swanson  304-762-2467
# 6              1007.0       Jeff      Winger           NaN
# 7              1008.0   Sherlock      Holmes  876|678|3469
# 8              1009.0    Gandalf         NaN           N/a
# 9              1010.0      Peter      Parker  123-545-5421
# 10             1011.0    Samwise      Gamgee           NaN
# 11             1012.0      Harry      Potter    7066950392
# 12             1013.0        Don      Draper  123-543-2345
# 13             1014.0     Leslie       Knope  876|678|3469
# 14             1015.0       Toby  Flenderson  304-762-2467
# ...

# %%
#df["Phone_Number"] = df["Phone_Number"].apply(lambda x: str(x))
#df["Phone_Number"] = df["Phone_Number"].apply(lambda x: x[0:3] + '-' + x[3:6] +'-' + x[6:10])
df["Phone_Number"] = df["Phone_Number"].str.replace('nan--','')
df["Phone_Number"] = df["Phone_Number"].str.replace('--','')
df
# Out:
#            CustomerID First_Name   Last_Name  Phone_Number  \
# 0              1001.0      Frodo     Baggins  123-545-5421
# 1              1002.0       Abed       Nadir  123-643-9775
# 2              1003.0     Walter       White
# 3              1004.0     Dwight     Schrute  123-543-2345
# 4              1005.0        Jon        Snow  876-678-3469
# 5              1006.0        Ron     Swanson  304-762-2467
# 6              1007.0       Jeff      Winger
# 7              1008.0   Sherlock      Holmes  876-678-3469
# 8              1009.0    Gandalf         NaN
# 9              1010.0      Peter      Parker  123-545-5421
# 10             1011.0    Samwise      Gamgee
# 11             1012.0      Harry      Potter
# 12             1013.0        Don      Draper  123-543-2345
# 13             1014.0     Leslie       Knope  876-678-3469
# 14             1015.0       Toby  Flenderson  304-762-2467
# 15             1016.0        Ron     Weasley  123-545-5421
# ...

# %%
#df["Address"].apply(lambda x: str(x))
df[["Street_Address","State","Zip_Code"]] = df["Address"].str.split(',',n=2, expand=True)
df
# Out:
#            CustomerID First_Name   Last_Name  Phone_Number  \
# 0              1001.0      Frodo     Baggins  123-545-5421
# 1              1002.0       Abed       Nadir  123-643-9775
# 2              1003.0     Walter       White
# 3              1004.0     Dwight     Schrute  123-543-2345
# 4              1005.0        Jon        Snow  876-678-3469
# 5              1006.0        Ron     Swanson  304-762-2467
# 6              1007.0       Jeff      Winger
# 7              1008.0   Sherlock      Holmes  876-678-3469
# 8              1009.0    Gandalf         NaN
# 9              1010.0      Peter      Parker  123-545-5421
# 10             1011.0    Samwise      Gamgee
# 11             1012.0      Harry      Potter
# 12             1013.0        Don      Draper  123-543-2345
# 13             1014.0     Leslie       Knope  876-678-3469
# 14             1015.0       Toby  Flenderson  304-762-2467
# 15             1016.0        Ron     Weasley  123-545-5421
# ...

# %%
df["Do_Not_Contact"] = df["Do_Not_Contact"].str.replace('Yes','Y')
df["Do_Not_Contact"] = df["Do_Not_Contact"].str.replace('No','N')
df
# Out:
#            CustomerID First_Name   Last_Name  Phone_Number  \
# 0              1001.0      Frodo     Baggins  123-545-5421
# 1              1002.0       Abed       Nadir  123-643-9775
# 2              1003.0     Walter       White
# 3              1004.0     Dwight     Schrute  123-543-2345
# 4              1005.0        Jon        Snow  876-678-3469
# 5              1006.0        Ron     Swanson  304-762-2467
# 6              1007.0       Jeff      Winger
# 7              1008.0   Sherlock      Holmes  876-678-3469
# 8              1009.0    Gandalf         NaN
# 9              1010.0      Peter      Parker  123-545-5421
# 10             1011.0    Samwise      Gamgee
# 11             1012.0      Harry      Potter
# 12             1013.0        Don      Draper  123-543-2345
# 13             1014.0     Leslie       Knope  876-678-3469
# 14             1015.0       Toby  Flenderson  304-762-2467
# 15             1016.0        Ron     Weasley  123-545-5421
# ...

# %%
#df = df.replace('N/a','')
#df = df.replace('NaN','')

df = df.fillna('')
df
# Out:
#           CustomerID First_Name   Last_Name  Phone_Number  \
# 0             1001.0      Frodo     Baggins  123-545-5421
# 1             1002.0       Abed       Nadir  123-643-9775
# 2             1003.0     Walter       White
# 3             1004.0     Dwight     Schrute  123-543-2345
# 4             1005.0        Jon        Snow  876-678-3469
# 5             1006.0        Ron     Swanson  304-762-2467
# 6             1007.0       Jeff      Winger
# 7             1008.0   Sherlock      Holmes  876-678-3469
# 8             1009.0    Gandalf
# 9             1010.0      Peter      Parker  123-545-5421
# 10            1011.0    Samwise      Gamgee
# 11            1012.0      Harry      Potter
# 12            1013.0        Don      Draper  123-543-2345
# 13            1014.0     Leslie       Knope  876-678-3469
# 14            1015.0       Toby  Flenderson  304-762-2467
# 15            1016.0        Ron     Weasley  123-545-5421
# ...

# %%
for x in df.index:
    if df.loc[x,"Do_Not_Contact"] == 'Y' or df.loc[x,"Do_Not_Contact"] == '':
        df.drop(x, inplace=True)
df
# Out:
#    CustomerID First_Name   Last_Name  Phone_Number  \
# 0      1001.0      Frodo     Baggins  123-545-5421
# 4      1005.0        Jon        Snow  876-678-3469
# 6      1007.0       Jeff      Winger
# 7      1008.0   Sherlock      Holmes  876-678-3469
# 9      1010.0      Peter      Parker  123-545-5421
# 10     1011.0    Samwise      Gamgee
# 12     1013.0        Don      Draper  123-543-2345
# 13     1014.0     Leslie       Knope  876-678-3469
# 14     1015.0       Toby  Flenderson  304-762-2467
# 15     1016.0        Ron     Weasley  123-545-5421
# 16     1017.0   Michael        Scott  123-643-9775
# 19     1020.0     Anakin   Skywalker  876-678-3469
# 20     1020.0     Anakin   Skywalker  876-678-3469
#
#                            Address Paying Customer Do_Not_Contact  \
# 0            123 Shire Lane, Shire               Y              N
# 4                 123 Dragons Road               Y              N
# 6                1209 South Street               N              N
# ...

# %%
df = df.reset_index(drop=True)
df
# Out:
#    CustomerID First_Name   Last_Name  Phone_Number  \
# 0      1001.0      Frodo     Baggins  123-545-5421
# 1      1005.0        Jon        Snow  876-678-3469
# 2      1007.0       Jeff      Winger
# 3      1008.0   Sherlock      Holmes  876-678-3469
# 4      1010.0      Peter      Parker  123-545-5421
# 5      1011.0    Samwise      Gamgee
# 6      1013.0        Don      Draper  123-543-2345
# 7      1014.0     Leslie       Knope  876-678-3469
# 8      1015.0       Toby  Flenderson  304-762-2467
# 9      1016.0        Ron     Weasley  123-545-5421
# 10     1017.0   Michael        Scott  123-643-9775
# 11     1020.0     Anakin   Skywalker  876-678-3469
# 12     1020.0     Anakin   Skywalker  876-678-3469
#
#                            Address Paying Customer Do_Not_Contact  \
# 0            123 Shire Lane, Shire               Y              N
# 1                 123 Dragons Road               Y              N
# 2                1209 South Street               N              N
# ...
